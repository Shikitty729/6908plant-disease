# %%
import os
import json
import logging
from datetime import datetime
import google.generativeai as genai

# API key setup
API_KEY = "AIzaSyB6XcIyV8OKawaMydSkVSL8avK3dJ6QvGg"  # Replace with your actual API key
genai.configure(api_key=API_KEY)

class PlantHealthAgent:
    def __init__(self, role: str, capabilities: list, backstory: str, personality: str = "") -> None:
        self.role = role
        self.capabilities = capabilities
        self.backstory = backstory
        self.personality = personality
        self.model = genai.GenerativeModel('gemini-1.5-pro')  # Using Gemini 1.5 Pro model

# Create a single unified agent
plant_health_agent = PlantHealthAgent(
    role="Plant Disease Diagnostician and Care Specialist",
    capabilities=[
        "Plant disease identification and confirmation",
        "Symptom analysis and progression understanding",
        "Treatment planning and recommendation",
        "Prevention strategies and long-term care"
    ],
    backstory="A seasoned plant pathologist and horticulturist with extensive experience diagnosing and treating plant diseases across various species. Combined expertise in laboratory diagnostics and practical garden management enables comprehensive plant health care from identification through recovery and prevention.",
    personality="Methodical, detail-oriented, and compassionate about plant health with a practical approach to disease management.",
)

class Task:
    def __init__(self, task_type: str, description: str, agent, expected_output: str, context=None) -> None:
        self.task_type = task_type
        self.description = description
        self.agent = agent
        self.expected_output = expected_output
        self.context = context or []

# Define all task types with the same agent
diagnosis_task = Task(
    task_type="DISEASE_DIAGNOSIS",
    description="""Provide a detailed diagnosis for the specified plant disease.

    Diagnosis Requirements:
    1. Confirm the disease identity based on the provided name and plant type
    2. Detail the causative agent (fungus, bacteria, virus, etc.) and its biology
    3. Describe the common symptoms and how they manifest
    4. Explain how the disease typically spreads and under what conditions it thrives
    5. Identify disease progression stages if applicable
    6. Note any similar diseases that might be confused with this condition

    Use accurate scientific terminology while maintaining accessibility for home gardeners.""",
    agent=plant_health_agent,
    expected_output="""A comprehensive disease profile containing:
    1. Disease confirmation and scientific classification
    2. Causative agent details
    3. Full symptom description
    4. Transmission and environmental factors
    5. Clear, accessible language with scientific accuracy"""
)

treatment_task = Task(
    task_type="TREATMENT_PLAN",
    description="""Develop a complete treatment plan for the diagnosed plant disease.

    Treatment Plan Requirements:
    1. Recommend immediate containment measures to prevent spread
    2. Provide a prioritized list of treatment options (organic, chemical, biological)
    3. Include specific product recommendations with application methods and timing
    4. Detail proper sanitization and tool handling procedures
    5. Address whether affected plant parts should be removed or treated
    6. Provide guidance on monitoring treatment effectiveness

    Consider both effectiveness and environmental impact of treatments.""",
    agent=plant_health_agent,
    expected_output="""A detailed treatment protocol including:
    1. Containment strategies
    2. Specific treatment options with application instructions
    3. Tool and garden hygiene protocols
    4. Timeline for treatment application
    5. Clear guidance on plant material handling
    6. Treatment success indicators"""
)

prevention_task = Task(
    task_type="PREVENTION_CARE_PLAN",
    description="""Create a long-term prevention and care plan to maintain plant health after treatment.

    Prevention Plan Requirements:
    1. Suggest optimal growing conditions to minimize disease recurrence
    2. Recommend preventative measures and maintenance routines
    3. Provide guidance on proper watering, fertilization, and pruning
    4. Suggest companion plants or cultural practices that reduce disease risk
    5. Outline a monitoring schedule for early detection of recurrence
    6. Include seasonal considerations for year-round protection

    The plan should be practical for the average gardener to implement.""",
    agent=plant_health_agent,
    expected_output="""A comprehensive prevention strategy including:
    1. Optimal growing conditions
    2. Preventative care routines
    3. Cultural practices for disease resistance
    4. Monitoring protocols
    5. Seasonal adjustments
    6. Long-term plant health strategies"""
)

def run_task(task: Task, input_text: str) -> str:
    try:
        system_input = (
            f"Agent Details:\n"
            f"Role: {task.agent.role}\n"
            f"Capabilities: {', '.join(task.agent.capabilities)}\n"
            f"Backstory: {task.agent.backstory}\n"
            f"Personality: {task.agent.personality}\n"
            f"Current Task Type: {task.task_type}\n"
        )
        task_input = (
            f"Task Details:\n"
            f"Task Description: {task.description}\n"
            f"Expected Output: {task.expected_output}\n"
            f"Input for Task:\n{input_text}\n"
        )

        # Use Google Gemini directly
        prompt = f"{system_input}\n\n{task_input}"
        response = task.agent.model.generate_content(prompt)
        return response.text
    except Exception as e:
        logging.error(f"Error in task '{task.task_type}': {e}")
        return f"Error in {task.task_type}: {e}"

def get_user_input(disease_name: str, plant_type: str) -> dict:
    return {
        "disease_name": disease_name,
        "plant_type": plant_type,
        "date": datetime.now().strftime("%Y-%m-%d")
    }

def main(disease_name, plant_type):
    print(f"Plant Disease Analysis: {disease_name} on {plant_type}")

    user_input = get_user_input(disease_name, plant_type)
    print("\nGenerating plant health assessment")
    for key, value in user_input.items():
        print(f"{key}: {value}")

    # Track the current assessment state in a dictionary
    assessment_state = {
        "user_input": user_input,
        "diagnosis": None,
        "treatment_plan": None,
        "prevention_plan": None
    }

    user_input_str = json.dumps(user_input, indent=2)

    # Step 1: Disease Diagnosis
    print("\nGenerating Diagnosis")
    diagnosis = run_task(diagnosis_task, user_input_str)
    assessment_state["diagnosis"] = diagnosis
    print("\nDISEASE DIAGNOSIS:")
    print(diagnosis)

    # Step 2: Treatment Planning
    print("\nDeveloping Treatment Plan")
    treatment_input = f"{user_input_str}\n\nDisease Diagnosis:\n{diagnosis}"
    treatment_plan = run_task(treatment_task, treatment_input)
    assessment_state["treatment_plan"] = treatment_plan
    print("\nTREATMENT PLAN:")
    print(treatment_plan)

    # Step 3: Prevention Planning
    print("\nCreating Prevention and Long-term Care Plan")
    prevention_input = f"{user_input_str}\n\nDisease Diagnosis:\n{diagnosis}\n\nTreatment Plan:\n{treatment_plan}"
    prevention_plan = run_task(prevention_task, prevention_input)
    assessment_state["prevention_plan"] = prevention_plan
    print("\nPREVENTION & CARE PLAN:")
    print(prevention_plan)

    save_plant_health_plan(user_input, diagnosis, treatment_plan, prevention_plan)

def save_plant_health_plan(user_input, diagnosis, treatment_plan, prevention_plan):
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    filename = f"Plant_Health_Plan_{user_input['disease_name'].replace(' ', '_')}_{timestamp}.txt"

    with open(filename, "w") as f:
        f.write(f"PLANT DISEASE ASSESSMENT: {user_input['disease_name']} on {user_input['plant_type']}\n")
        f.write("ASSESSMENT DETAILS:\n")
        f.write(f"Disease: {user_input['disease_name']}\n")
        f.write(f"Plant Type: {user_input['plant_type']}\n")
        f.write(f"Date: {user_input['date']}\n\n")

        f.write("DISEASE DIAGNOSIS:\n")
        f.write(diagnosis)
        f.write("\n\n")

        f.write("TREATMENT PLAN:\n")
        f.write(treatment_plan)
        f.write("\n\n")

        f.write("PREVENTION & CARE PLAN:\n")
        f.write(prevention_plan)

if __name__ == "__main__":
    # Example usage: main("Powdery Mildew", "Rose")
    disease_name = input("Enter plant disease name: ")
    plant_type = input("Enter plant type: ")
    main(disease_name, plant_type)
# Out:
# Enter plant disease name: tomato
# Enter plant type: early blight
# Plant Disease Analysis: tomato on early blight
#
# Generating plant health assessment
# disease_name: tomato
# plant_type: early blight
# date: 2025-05-01
#
# Generating Diagnosis
#
# DISEASE DIAGNOSIS:
# ## Early Blight of Tomato Diagnosis
#
# **1. Disease Confirmation and Scientific Classification:**
#
# The disease affecting your tomatoes is confirmed as **early blight**, caused by the fungal pathogen *Alternaria solani*.  It's a common and destructive disease affecting tomatoes and other members of the Solanaceae family (e.g., potatoes, peppers, eggplant).
#
#
# **2. Causative Agent Details:**
#
# *Alternaria solani* is an ascomycete fungus. It produces spores (conidia) that are easily dispersed by wind, splashing water, and on gardening tools or clothing. The fungus overwinters in infected plant debris left in the soil or on volunteer tomato plants.  It can also survive on infected potato tubers.
#
#
# **3. Symptom Description:**
#
# Early blight symptoms typically appear first on older, lower leaves as small, dark brown spots with concentric rings, often described as "target" or "bullseye" patterns.  These lesions can enlarge, causing significant leaf area to become necrotic (dead) and eventually leading to leaf drop.  Stem lesions are also common, appearing as dark, elongated, and slightly sunken areas. These can girdle the stem, disrupting nutrient and water flow, which weakens the plant.  On the fruit, early blight infections typically start at the stem end and appear as dark, leathery, sunken lesions with concentric rings.  Infected fruit often drops prematurely.
#
#
# **4. Transmission and Environmental Factors:**
#
# * **Transmission:**  The fungus spreads primarily through airborne conidia carried by wind and splashing rain or irrigation water.  Contact with infected plant debris, tools, or even clothing can also transmit the disease.
# * **Environmental Factors:**  Early blight thrives in warm (75-85°F), humid conditions with prolonged leaf wetness. Frequent rainfall, overhead irrigation, and dense planting contribute to disease development.  Stress factors such as nutrient deficiencies or insect damage can also make plants more susceptible.
#
#
# **5. Disease Progression Stages:**
#
# * **Initial Infection:** Small, dark spots appear on lower leaves.
# * **Lesion Expansion:** Spots enlarge and develop concentric rings, often with yellow halos.
# * **Defoliation:** Severely infected leaves turn yellow and drop prematurely.
# * **Stem Infection:** Dark, sunken lesions develop on stems, potentially girdling them.
# * **Fruit Infection:** Dark, leathery lesions appear on fruit, usually starting at the stem end.
# * **Plant Decline:** Weakened plants produce fewer and smaller fruit and may eventually die.
#
#
# **6. Similar Diseases:**
#
# Early blight can sometimes be confused with other fungal leaf spots, such as **Septoria leaf spot**.  Septoria leaf spot lesions are typically smaller and more numerous than early blight lesions and lack the characteristic concentric rings.  Accurate diagnosis is crucial for implementing effective management strategies.  If in doubt, consult with your local extension service for laboratory confirmation.
#
#
# Developing Treatment Plan
#
# TREATMENT PLAN:
# ## Early Blight of Tomato Treatment Plan
#
# This treatment plan outlines a comprehensive strategy for managing early blight on your tomatoes, emphasizing both effectiveness and environmental responsibility.
#
# **1. Containment Strategies (Immediate Action):**
#
# * **Isolate affected plants:**  If possible, move potted tomato plants away from healthy ones to minimize disease spread. For in-ground plants, increase spacing between plants to improve air circulation.
# * **Remove infected debris:** Carefully collect and remove all fallen leaves, stems, and infected fruit from the garden and surrounding area.  Do not compost infected material.  Bag and dispose of it in the trash to prevent the fungus from overwintering and re-infecting your garden next season.
# * **Avoid overhead watering:**  Water at the base of the plants in the early morning to allow foliage to dry quickly. Wet leaves provide ideal conditions for fungal growth. Use soaker hoses or drip irrigation if possible.
# * **Control weeds and volunteer tomatoes:** These can harbor the fungus.  Remove them promptly.
#
# **2. Treatment Options (Prioritized List):**
#
# **A. Organic Treatments (Preferred):**
#
# * **Copper-based fungicides:** These are effective against early blight and are allowed in organic gardening.  Look for products containing copper hydroxide, copper sulfate, or copper oxychloride.
#     * **Application:** Follow product label instructions carefully for dosage and application frequency. Typically, apply every 7-10 days, or as needed, especially after rain or overhead watering. Ensure thorough coverage of all plant surfaces, including the undersides of leaves.
# * **Potassium bicarbonate:**  This acts as a contact fungicide and can help suppress early blight.
#     * **Application:** Mix 1-2 teaspoons of potassium bicarbonate per gallon of water and spray thoroughly on plants. Apply every 7-10 days, or as needed.
# * **Biological fungicides:** Products containing *Bacillus subtilis* can offer some control of early blight.
#     * **Application:** Follow product label instructions. These often require more frequent applications than copper fungicides.
#
# **B. Chemical Treatments (Use with caution):**
#
# * **Chlorothalonil:**  A broad-spectrum fungicide effective against early blight.  However, it's a synthetic chemical and should be used as a last resort after exhausting organic options.
#     * **Application:** Follow product label instructions strictly.  Wear protective clothing, including gloves, goggles, and a mask, when applying.  Observe all safety precautions and re-entry intervals.
#
# **3. Specific Product Recommendations and Application Timing:**
#
# * **Bonide Copper Fungicide:**  A readily available copper-based fungicide suitable for organic gardening. Apply every 7-10 days.
# * **Southern Ag Liquid Copper Fungicide:** Another effective copper option. Follow label instructions.
# * **Serenade Garden Disease Control (Bacillus subtilis):** A biological fungicide that can be used preventatively or at the first sign of disease. Apply every 7-10 days.
#
# **4. Sanitization and Tool Handling Procedures:**
#
# * **Clean tools regularly:** Disinfect all gardening tools (pruners, shears, trowels, etc.) after each use with a solution of 1 part bleach to 9 parts water or 70% rubbing alcohol. Allow tools to air dry completely.
# * **Wash hands:**  Thoroughly wash your hands with soap and water after working with infected plants or handling gardening tools.
#
# **5. Plant Material Handling:**
#
# * **Remove affected leaves:**  Prune heavily infected leaves and dispose of them as described above.  This helps reduce the source of fungal spores.  For severely infected plants, consider removing the entire plant to protect healthy ones.
# * **Do not compost infected material:**  Composting may not reach temperatures high enough to kill the fungus.
#
# **6. Monitoring Treatment Effectiveness:**
#
# * **Observe new growth:**  After beginning treatment, monitor plants for new signs of disease. Look for healthy new growth free of spots or lesions.
# * **Reduced lesion development:** Existing lesions should stop enlarging or developing further.
# * **Decreased defoliation:**  The rate of leaf drop should decrease.
#
#
# **7. Timeline for Treatment Application:**
#
# * **Initial application:** Apply the chosen treatment immediately upon diagnosis.
# * **Follow-up applications:** Continue applications according to product label instructions or as recommended above, typically every 7-10 days.  Adjust frequency based on disease severity and weather conditions. Continue treatments until symptoms subside, and weather conditions are no longer favorable for disease development.
#
# **8.  Important Note:**  Always follow product label instructions precisely for application rates, safety precautions, and pre-harvest intervals.  If you are unsure about which treatment to use, consult with your local agricultural extension office or a certified arborist.
#
#
# Creating Prevention and Long-term Care Plan
#
# PREVENTION & CARE PLAN:
# ## Long-Term Prevention and Care Plan for Tomato Early Blight
#
# This plan outlines a comprehensive strategy for maintaining tomato plant health and preventing early blight recurrence after initial treatment.
#
# **1. Optimal Growing Conditions:**
#
# * **Sunlight:**  Provide at least 6-8 hours of direct sunlight daily.  Sunlight helps keep foliage dry and inhibits fungal growth.
# * **Soil:** Well-drained soil is crucial. Amend heavy clay soils with compost or other organic matter to improve drainage.  A slightly acidic soil pH (6.0-6.8) is ideal.
# * **Spacing:** Adequate spacing between plants (2-3 feet) promotes good air circulation, reducing humidity and leaf wetness.
# * **Air Circulation:** Proper spacing and pruning are essential for good airflow.  Consider staking or caging plants to keep them off the ground and improve air circulation.
#
# **2. Preventative Care Routines:**
#
# * **Crop Rotation:**  Rotate tomatoes with non-Solanaceae crops (e.g., beans, lettuce, carrots) every 2-3 years to break the disease cycle.  Avoid planting tomatoes, potatoes, peppers, and eggplants in the same location year after year.
# * **Sanitation:**  At the end of the growing season, meticulously remove all plant debris, including stems, leaves, and fruit, and dispose of it in the trash. Do not compost infected plant material.
# * **Seed Starting:** Start with disease-free seeds or transplants from reputable sources.
# * **Mulching:** Apply a 2-3 inch layer of organic mulch (straw, shredded bark) around plants.  This helps suppress weeds, conserve moisture, and prevents soil-borne spores from splashing onto lower leaves.
#
# **3. Cultural Practices for Disease Resistance:**
#
# * **Watering:** Water deeply and less frequently at the base of the plants, avoiding wetting the foliage. Water early in the morning to allow leaves to dry before nightfall.
# * **Fertilization:** Provide balanced nutrition. Avoid excessive nitrogen fertilization, which can promote lush growth that is more susceptible to disease.  Use a slow-release fertilizer or side-dress with compost tea.
# * **Pruning:**  Prune lower leaves that are close to the ground to improve air circulation and reduce humidity. Remove suckers (small shoots that grow from the junction of the main stem and branches) to promote air circulation and direct energy to fruit production.
#
# **4. Companion Planting:**
#
# * **Basil, parsley, and marigolds:** These herbs are believed to repel insects that can spread disease and may also have some antifungal properties.
#
# **5. Monitoring Protocols:**
#
# * **Regular Inspection:** Inspect plants at least once a week, especially during periods of warm, humid weather. Pay close attention to the lower leaves for any signs of early blight.
# * **Early Detection:** Catching the disease early is key to successful management. At the first sign of symptoms, implement appropriate control measures.
# * **Record Keeping:** Maintain a garden journal to track disease occurrences, weather conditions, and treatment applications. This information can be valuable for future prevention efforts.
#
# **6. Seasonal Adjustments:**
#
# * **Spring:**  Start with clean seed trays and potting mix. Harden off seedlings before transplanting.
# * **Summer:** Monitor closely for disease development, especially during humid periods.  Water consistently and provide adequate air circulation.
# * **Fall:** After harvest, promptly remove all plant debris and clean up the garden area.  Prepare the soil for next season by amending with compost or other organic matter.
# * **Winter:** Plan your crop rotation for the next season.  Store seeds in a cool, dry place.
#
# **7. Long-Term Plant Health Strategies:**
#
# * **Build Soil Health:** Healthy soil promotes healthy plants that are more resistant to disease.  Incorporate compost, cover crops, and other organic matter to improve soil structure, drainage, and nutrient content.
# * **Variety Selection:** Consider planting disease-resistant tomato varieties.  Look for varieties labeled as resistant or tolerant to early blight (e.g., 'Mountain Magic', 'Defiant', 'Juliet').
# * **Continued Vigilance:** Early blight can reoccur, so ongoing monitoring and preventative practices are crucial for long-term plant health and productivity.
#
#
# This long-term prevention and care plan, combined with prompt action at the first sign of disease, will help you protect your tomato plants from early blight and enjoy a bountiful harvest.  Remember to consult with your local agricultural extension office or a certified arborist if you have any questions or concerns.

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-3.0.4-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.13.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dash) (1.17.0)
# Downloading dash-3.0.4-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 127.1 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 12.0 MB/s eta 0:00:00
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 25.4 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: Werkzeug, retrying, Flask, dash
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 dash-3.0.4 retrying-1.3.4

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd

df = px.data.iris()  # 自带数据集

app = dash.Dash(__name__)

app.layout = html.Div([
    html.H1("Iris Dashboard"),
    dcc.Dropdown(
        options=[{"label": col, "value": col} for col in df.columns if col != "species"],
        value="sepal_length",
        id="feature-dropdown"
    ),
    dcc.Graph(id="scatter-plot")
])

@app.callback(
    dash.dependencies.Output("scatter-plot", "figure"),
    dash.dependencies.Input("feature-dropdown", "value")
)
def update_graph(feature):
    fig = px.scatter(df, x=feature, y="sepal_width", color="species")
    return fig

if __name__ == "__main__":
    app.run(debug=True)
